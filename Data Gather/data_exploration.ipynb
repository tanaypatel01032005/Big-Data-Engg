# %% [markdown]
# # Basic Data Exploration
#
# This notebook performs basic exploratory data analysis on the library dataset.

# %%
import pandas as pd

# Load the dataset
df = pd.read_csv('Data/dau_library_data.csv',encoding='latin1')

# Display basic information
print("Dataset shape:", df.shape)
print("\nColumns:", list(df.columns))
# Out:
# Dataset shape: (36358, 21)
#
# Columns: ['Acc. Date', 'Acc. No.', 'Title', 'ISBN', 'Author/Editor', 'Ed./Vol.', 'Place & Publisher', 'Year', 'Page(s)', 'Class No./Book No.', 'Unnamed: 10', 'Unnamed: 11', 'Unnamed: 12', 'Unnamed: 13', 'Unnamed: 14', 'Unnamed: 15', 'Unnamed: 16', 'Unnamed: 17', 'Unnamed: 18', 'Unnamed: 19', 'Unnamed: 20']
# C:\Users\tanay\AppData\Local\Temp\ipykernel_25200\2331472601.py:4: DtypeWarning: Columns (12,13,14,15,16,17,18,19,20) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('Data/dau_library_data.csv',encoding='latin1')

# %%
# Display first few rows
df.head()
# Out:
#     Acc. Date  Acc. No.                                              Title  \
# 0  20-01-2017         1  Network design : management and technical pers...
# 1  08-09-2001         2  Multimedia information analysis and retrieval ...
# 2  08-09-2001         3  Multimedia systems : delivering, generating, a...
# 3  05-09-2001         4  Principles of Data Mining and Knowledge Discovery
# 4  09-08-2001         5  Focusing solutions for data mining : analytica...
#
#             ISBN             Author/Editor Ed./Vol.  \
# 0     0849334047  Mann-Rubinson, Teresa C.      NaN
# 1  9783540648260          Ip, Horace H. S.      NaN
# 2     1852332484               Morris, Tim      NaN
# 3  9783540410669           Zytkov, Jan. M.      NaN
# 4     3540664297          Reinartz, Thomas      NaN
#
#             Place & Publisher    Year        Page(s) Class No./Book No.  ...  \
# 0      Boca Raton: CRC Press,  1999.0        405 p.;          004.6 MAN  ...
# ...

# %%
# Basic statistics
df.describe(include='all')
# Out:
#          Acc. Date     Acc. No.                             Title     ISBN  \
# count        36179  36358.00000                             36358    36358
# unique        2568          NaN                             30900    31644
# top     31-03-2023          NaN  Great books of the Western world  Sahitya
# freq           366          NaN                                61       63
# mean           NaN  18179.50000                               NaN      NaN
# std            NaN  10495.79488                               NaN      NaN
# min            NaN      1.00000                               NaN      NaN
# 25%            NaN   9090.25000                               NaN      NaN
# 50%            NaN  18179.50000                               NaN      NaN
# 75%            NaN  27268.75000                               NaN      NaN
# max            NaN  36358.00000                               NaN      NaN
#
# ...

# %%
# Check for missing values
df.isnull().sum()
# Out:
# Acc. Date               179
# Acc. No.                  0
# Title                     0
# ISBN                      0
# Author/Editor            63
# Ed./Vol.              30579
# Place & Publisher         0
# Year                    170
# Page(s)                   1
# Class No./Book No.        0
# Unnamed: 10           36335
# Unnamed: 11           36338
# Unnamed: 12           36345
# Unnamed: 13           36345
# Unnamed: 14           36347
# Unnamed: 15           36348
# Unnamed: 16           36349
# Unnamed: 17           36352
# Unnamed: 18           36352
# Unnamed: 19           36356
# Unnamed: 20           36356
# dtype: int64

# %%
df = df.drop(columns=["Unnamed: 10", "Unnamed: 11", "Unnamed: 12", "Unnamed: 13", "Unnamed: 14", "Unnamed: 15", "Unnamed: 16", "Unnamed: 17", "Unnamed: 18", "Unnamed: 19", "Unnamed: 20"],inplace=True)
